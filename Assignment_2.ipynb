# %% [markdown]
# <a href="https://colab.research.google.com/github/christian8184/MUSC-3264/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# Cloning into 'musicComputing2026'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 106 (delta 47), reused 11 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (106/106), 13.45 MiB | 14.08 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
def plotAudio2(sig,sampleRate,title):

   # create time vector
    t = np.arange(len(sig)) / sampleRate

    # plot waveform
    plt.figure()
    plt.plot(t, sig)
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.title(title)
    plt.show()

    # add in the code from Assignment 2

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):

   # compute stft
    S = librosa.stft(sig, n_fft=winSize)

    # magnitude
    S_mag = np.abs(S)

    # convert to decibels
    S_db = librosa.amplitude_to_db(S_mag, ref=np.max)

    # plot spectrogram
    plt.figure()

    if specType == 'log':
        librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='log')
    else:
        librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='linear')

    plt.title(title)
    plt.colorbar()
    plt.show()

    # create a normalized spectrogram
    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    # then make all of values in the spectrogram positive with np.abs()
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()

    # display the normalized spectrogram with a log frequency scale

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):
    plotAudio2(sig, sr, title)
    plotAudioFreqDomain(sig, sr, title, winSize, specType)

    #call plotAudio2

    #call plotAudioFreqDomain

# %%
sig , sr = librosa.load('musicComputing2026/audioFiles/avm.wav')

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'

plotAudioFunc(sig, sr, title, winSize, specType)

#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'

plotAudioFunc(sig, sr, title, winSize, specType)

#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'

plotAudioFunc(sig, sr, title, winSize, specType)

#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'

plotAudioFunc(sig, sr, title, winSize, specType)

# call plotAudioFunc
