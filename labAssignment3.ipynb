# %% [markdown]
# <a href="https://colab.research.google.com/github/christian8184/MUSC-3264/blob/main/labAssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# fatal: destination path 'musicComputing2026' already exists and is not an empty directory.

# %%
def plotAudio2(sig,sampleRate,title):

  time = np.arange(0,len(sig)) / sampleRate

  plt.plot(time,sig)
  plt.title(title)
  plt.xlabel('Time (s)')
  plt.ylabel('Amplitude')
  plt.show()

    # add in the code from Assignment 2

# %%
def plotAudioFreqDomain(sig, sr, title, winSize, specType):

    X = librosa.stft(sig, n_fft=winSize)
    Xdb = librosa.amplitude_to_db(abs(X))
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis=specType)
    plt.title(title)
    plt.show()

    # create a normalized spectrogram
    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    # then make all of values in the spectrogram positive with np.abs()
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()

    # display the normalized spectrogram with a log frequency scale

# %%
def plotAudioFunc(sig, sr, title, winSize, specType):
    plotAudio2(sig, sr, title)
    plotAudioFreqDomain(sig, sr, title, winSize, specType)

    #call plotAudio2

    #call plotAudioFreqDomain

# %%
sig , sr = librosa.load('musicComputing2026/audioFiles/avm.wav')

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'
plotAudioFunc(sig, sr, 'Ave Maria', 2048, 'linear')
#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'
plotAudioFunc(sig, sr, 'Ave Maria', 2048, 'log')
#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'
plotAudioFunc(sig, sr, 'Ave Maria', 256, 'linear')
#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'
plotAudioFunc(sig, sr, 'Ave Maria', 256, 'log')
# call plotAudioFunc
